# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHE0609/python/blob/main/one_encoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
data={"color":["red","blue","green","yellow","purple"]}
df=pd.DataFrame(data)
df.head()
# Out:
#     color
# 0     red
# 1    blue
# 2   green
# 3  yellow
# 4  purple

# %%
label_encoder=LabelEncoder()
df["color_label"]=label_encoder.fit_transform(df["color"])
df.head()
# Out:
#     color  color_label
# 0     red            3
# 1    blue            0
# 2   green            1
# 3  yellow            4
# 4  purple            2

# %%
one_hot_encoder=OneHotEncoder(sparse_output=False)
color_encoded=one_hot_encoder.fit_transform(df[["color"]])
color_encoded_df=pd.DataFrame(color_encoded,columns=one_hot_encoder.get_feature_names_out(["color"]))
df=pd.concat([df,color_encoded_df],axis=1)
df.head()
# Out:
#     color  color_label  color_blue  color_green  color_purple  color_red  \
# 0     red            3         0.0          0.0           0.0        1.0
# 1    blue            0         1.0          0.0           0.0        0.0
# 2   green            1         0.0          1.0           0.0        0.0
# 3  yellow            4         0.0          0.0           0.0        0.0
# 4  purple            2         0.0          0.0           1.0        0.0
#
#    color_yellow
# 0           0.0
# 1           0.0
# 2           0.0
# 3           1.0
# 4           0.0
